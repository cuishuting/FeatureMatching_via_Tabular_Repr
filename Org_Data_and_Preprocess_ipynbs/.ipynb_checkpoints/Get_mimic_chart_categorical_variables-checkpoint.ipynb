# %% [markdown]
# # test on mimic_chart_MV's categorical first

# %% [markdown]
# * Get the categorical itemids list for mimic_chart_MV (categorical unique values <= 10)
# * Get the final selected mimic_chart_MV hadmids from file "./data/mimic_chart_MV_only_numeric.csv"
# * write a function to get one-hot encoded categorical itemids' values:
#     * firstly transform the categorical itemids' recordings as transformation on numeric itemids' recordings before (n_rows: 24, cols are the itemids of selected categorical variables)
#     * then one-hot encoded each categorical variables under the structure got from last step

# %%
import pandas as pd
import numpy as np
import datetime
pd.options.mode.chained_assignment = None  # default='warn'

# %%
item_id_dbsource = pd.read_csv('./data/d_items_chartevents.csv')

# %%
list_itemid_cat_chart_MV = item_id_dbsource[(item_id_dbsource['dbsource']=='metavision') & (item_id_dbsource['param_type'].isin(['Checkbox']))]['itemid']

# %%
# the final hadm_id is the same with "hadm_id" in  mimic_chart_mv_only_numeric
mimic_chart_mv_only_numeric = pd.read_csv("./data/mimic_chart_MV_only_numeric.csv")

# %%
final_hadmids_chart_mv = mimic_chart_mv_only_numeric["hadm_id"].unique()

# %%
# org_chart_cv_data is the original form of all mimic_chart_mv data (the same form as what sandhya sent me) 
org_chart_mv_data = pd.read_csv("./data/mimic_chart_TS_metavision.csv")
# Out:
# /Users/shutingcui/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (8,10,13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
selected_chart_mv_data = org_chart_mv_data[org_chart_mv_data["hadm_id"].isin(final_hadmids_chart_mv)]
selected_chart_mv_data = selected_chart_mv_data[selected_chart_mv_data["itemid"].isin(list_itemid_cat_chart_MV)]
print("original chart mv data's shape: ", org_chart_mv_data.shape)
print("after filtering(hadmids and categorical itemids), selected_chart_cv data's shape: ", selected_chart_mv_data.shape)
# Out:
# original chart mv data's shape:  (26517961, 17)
# after filtering(hadmids and categorical itemids), selected_chart_cv data's shape:  (1833976, 17)

# %% [markdown]
# # We need to refilter selected_chart_mv_data and only leave those categorical variables whose unique values are <= 10

# %%
final_cat_itemids_list_chart_mv = []
chart_mv_data_gb_itemid = selected_chart_mv_data.groupby("itemid")
cur_selected_cat_itemids = selected_chart_mv_data["itemid"].unique()
for itemid in cur_selected_cat_itemids:
    cur_itemid_recordings = chart_mv_data_gb_itemid.get_group(itemid)
    if len(cur_itemid_recordings["value"].unique()) <= 10:
        final_cat_itemids_list_chart_mv.append(itemid)
print("all cat itemid: ", len(list_itemid_cat_chart_MV))
print("final cat itemids(unique values <= 10): ", len(final_cat_itemids_list_chart_mv))
# Out:
# all cat itemid:  307
# final cat itemids(unique values <= 10):  189

# %% [markdown]
# # After leaving only those cat itemids with <= 10 unique values, we need another filter step: calculating the recording frequency of each cat itemid as the fraction of recorded patients and only leave those itemids with recorded fraction >= 30%

# %%
selected_chart_mv_partial = selected_chart_mv_data[["hadm_id", "itemid"]]
selected_chart_mv_partial_gb_itemid = selected_chart_mv_partial.groupby("itemid")
cat_itemid_record_frequency_chart_mv = pd.DataFrame(np.zeros((1, len(final_cat_itemids_list_chart_mv))), columns=list(final_cat_itemids_list_chart_mv))
chart_mv_total_num_patients = len(selected_chart_mv_partial["hadm_id"].unique())

for itemid in final_cat_itemids_list_chart_mv:
    cur_itemid_recordings = selected_chart_mv_partial_gb_itemid.get_group(itemid)
    hadmid_record_cur_itemid = len(cur_itemid_recordings["hadm_id"].unique())
    cat_itemid_record_frequency_chart_mv.loc[0][itemid] = hadmid_record_cur_itemid / chart_mv_total_num_patients
    
cat_itemid_record_frequency_chart_mv = cat_itemid_record_frequency_chart_mv.T
cat_itemid_record_frequency_chart_mv.reset_index(inplace=True)
cat_itemid_record_frequency_chart_mv.rename(columns={"index": "itemid", 0: "fraction of recorded hadmid"}, inplace=True)
cat_itemid_record_frequency_chart_mv.sort_values(by=["fraction of recorded hadmid"], ascending=False, inplace=True, ignore_index=True)
with pd.option_context("display.max_rows", None, "display.max_columns", None):
    display(cat_itemid_record_frequency_chart_mv)
# for itemid in final_cat_itemids_list_chart_mv:
#     print(itemid)
#     
#     print(cur_itemid_recordings["value"].value_counts())
# Out:
#      itemid  fraction of recorded hadmid
# 0    224641                     0.998668
# 1    224168                     0.997336
# 2    227688                     0.921503
# 3    225103                     0.807422
# 4    225187                     0.755186
# 5    225185                     0.748335
# 6    225092                     0.669933
# 7    225094                     0.645385
# 8    227368                     0.589010
# 9    225106                     0.588344
# 10   226138                     0.583682
# 11   225118                     0.583492
# 12   225087                     0.571265
# 13   225113                     0.555709
# 14   225126                     0.553711
# 15   227367                     0.552141
# 16   226179                     0.548145
# 17   226137                     0.548002
# 18   225184                     0.538487
# 19   225067                     0.518316
# 20   225110                     0.516223
# 21   225122                     0.505899
# ...

# %%
print("before filtering itemids with less than 30% fraction of recorded hadmid: ", len(final_cat_itemids_list_chart_mv))
final_cat_itemids_chart_mv = list(cat_itemid_record_frequency_chart_mv[cat_itemid_record_frequency_chart_mv["fraction of recorded hadmid"] >= 0.3]["itemid"])
print("after filtering itemids with less than 30% fraction of recorded hadmid: ", len(final_cat_itemids_chart_mv))
# Out:
# before filtering itemids with less than 30% fraction of recorded hadmid:  189
# after filtering itemids with less than 30% fraction of recorded hadmid:  37

# %%
# final_cat_itemids_chart_mv
itemid_info_chart = pd.read_csv("./data/d_items_chartevents.csv")
selected_cat_itemid_chart_mv = itemid_info_chart[itemid_info_chart["itemid"].isin(final_cat_itemids_chart_mv)]
cat_itemid_chart_mv = selected_cat_itemid_chart_mv[["itemid", "label"]]
cat_itemid_chart_mv.reset_index(inplace=True, drop=True)
cat_itemid_chart_mv
# Out:
#     itemid                                              label
# 0   225184                                           Eye Care
# 1   225185                                          Skin Care
# 2   225187                                          Back Care
# 3   225210                       Arterial Line Zero/Calibrate
# 4   224168                                 Parameters Checked
# 5   227292                   Arterial Line Dressing Occlusive
# 6   227349                      High risk (>51) interventions
# 7   227367                        18 Gauge Dressing Occlusive
# 8   227368                        20 Gauge Dressing Occlusive
# 9   226169                              Subglottal Suctioning
# 10  226179                                  No wallet / money
# 11  226180                  Sexuality / reproductive problems
# 12  227688  Smoking Cessation Info Offered through BIDMC I...
# 13  224641                                          Alarms On
# ...

# %%
cat_itemid_chart_mv.to_csv("./data/selected_cat_itemid_label_chart_mv.csv", index=False)

# %%
print("before filter: 1. <=10 unique values 2. fraction of record patients: >= 30%:", selected_chart_mv_data.shape)
final_chart_mv_cat_itemid_recordings = selected_chart_mv_data[selected_chart_mv_data["itemid"].isin(final_cat_itemids_chart_mv)]
print("after filter: 1. <=10 unique values 2. fraction of record patients: >= 30%:", final_chart_mv_cat_itemid_recordings.shape)
# Out:
# before filter: 1. <=10 unique values 2. fraction of record patients: >= 30%: (1833976, 17)
# after filter: 1. <=10 unique values 2. fraction of record patients: >= 30%: (1405056, 17)

# %% [markdown]
# ## solve the problem: when applying value_counts() on mimic_chart_mv categorical itemids(they are all binary variables), the returned unique values contain non-unique values: 1 1 0 0 Reason for this phenominon: some type of value "1" is str, while other types of value "1" are int or float.
# * **transfer all those selected binary itemids's value type into 'integer'**

# %%
for itemid in final_cat_itemids_chart_mv:
    final_chart_mv_cat_itemid_recordings.loc[final_chart_mv_cat_itemid_recordings["itemid"]==itemid, ["value"]] = pd.to_numeric(final_chart_mv_cat_itemid_recordings[final_chart_mv_cat_itemid_recordings["itemid"]==itemid]["value"], downcast="integer", errors="coerce")

# %%
final_chart_mv_cat_itemid_record_gb_itemid = final_chart_mv_cat_itemid_recordings.groupby("itemid")
for itemid in final_cat_itemids_chart_mv:
    cur_itemid_recordings = final_chart_mv_cat_itemid_record_gb_itemid.get_group(itemid)
    print(itemid)
    print(cur_itemid_recordings["value"].value_counts())
# Out:
# 224641
# 1    128356
# 0       537
# Name: value, dtype: int64
# 224168
# 1    125274
# 0       269
# Name: value, dtype: int64
# 227688
# 1    65736
# 0      749
# Name: value, dtype: int64
# 225103
# 1    32218
# 0    10635
# Name: value, dtype: int64
# 225187
# 1    51303
# 0      534
# Name: value, dtype: int64
# 225185
# 1    49659
# 0      527
# Name: value, dtype: int64
# 225092
# 1    27577
# 0     7718
# Name: value, dtype: int64
# 225094
# 0    22908
# 1    10774
# Name: value, dtype: int64
# 227368
# 1    58518
# 0      791
# Name: value, dtype: int64
# 225106
# 0    17364
# 1    12751
# Name: value, dtype: int64
# 226138
# 0    44595
# 1    14107
# Name: value, dtype: int64
# 225118
# 0    25642
# 1     3804
# Name: value, dtype: int64
# 225087
# 0    16828
# 1    13394
# Name: value, dtype: int64
# 225113
# 0    16330
# 1    11787
# Name: value, dtype: int64
# 225126
# 0    26234
# 1     1960
# Name: value, dtype: int64
# 227367
# 1    56784
# 0      651
# ...

# %% [markdown]
# # function "Cur_Patient_24hr_cat_itemids_chart_mv":
# * this function is only applied on chart_mv(because only the chartevent dataset contains the categorical variables, the variables in labevent dataset are all numeric)
# * **For chart_mv:**
#     * because all the categorical variables in chart_mv are binary variables and we've already transfered all the "value" into integer type. Therefore there is no need to one-hot encoding these categorical variables in chart_mv
#     * transfer current patient's cat itemid's recordings into the form with 24 rows, each row represent a one-hour time window

# %%
final_chart_mv_cat_itemid_recordings.head()
# Out:
#            row_id  subject_id  hadm_id  icustay_id  itemid  \
# 230811  255752583        7936   144371      247302  227688
# 233818  255752587        7936   144371      247302  227688
# 234135  255753601        8081   175774      226082  227688
# 234336  255753615        8081   175774      226082  227688
# 234460  255753631        8081   175774      226082  227688
#
#                   charttime            storetime     cgid value  valuenum  \
# 230811  2157-11-12 17:02:00  2157-11-12 17:08:00  14757.0     1       1.0
# 233818  2157-11-12 18:12:00  2157-11-12 18:15:00  14757.0     1       1.0
# 234135  2125-07-11 21:21:00  2125-07-11 21:21:00  16436.0     1       1.0
# 234336  2125-07-11 21:55:00  2125-07-11 22:17:00  16436.0     1       1.0
# 234460  2125-07-11 23:54:00  2125-07-11 23:55:00  16436.0     1       1.0
#
#        valueuom  warning  error resultstatus stopped  expire_flag    dbsource
# 230811      NaN      0.0    0.0          NaN     NaN            0  metavision
# ...

# %%
mimic_icu_adm = pd.read_csv("./data/mimic_icuadmittime.csv")

# %% [markdown]
# # Below is the initial form of function to get the transformed categorical itemids' recordings for both chart_cv & chart_mv(before imputation). The final version of this function is the below one in chart_cv part

# %%
def Cur_Patient_24hr_cat_itemids_value(hadm_id):
    cur_dataset_af_gb_hadmid = final_chart_mv_cat_itemid_recordings.groupby("hadm_id")
    cur_adm_recordings = cur_dataset_af_gb_hadmid.get_group(hadm_id)[["hadm_id", "itemid", "charttime", "value"]]
    
    cur_icu_adm_time = mimic_icu_adm[mimic_icu_adm["hadm_id"] == hadm_id]["intime"].unique()[0]
    icu_adm_timestamp = datetime.datetime.timestamp(datetime.datetime.strptime(cur_icu_adm_time,"%Y-%m-%d %H:%M:%S"))
    cur_adm_recordings[["charttimestamp"]] = cur_adm_recordings[["charttime"]].apply((lambda x: datetime.datetime.timestamp(datetime.datetime.strptime(x["charttime"],"%Y-%m-%d %H:%M:%S"))), axis=1)
    cur_adm_recordings[["charttime_interval_after_icu_adm"]] = (cur_adm_recordings[["charttimestamp"]] - icu_adm_timestamp) / 3600
    cur_adm_recordings[["charttime_interval_after_icu_adm"]] = cur_adm_recordings[["charttime_interval_after_icu_adm"]].astype(int) + 1 # "+1" because astype(int) will only keep the integer part of the float number
    # for example: charttime_interval_after_icu_adm == 0.2, actually this belongs to the first one-hour window, so the result should be 1, not 0 (if returned directly by astype(int))
    cur_adm_recordings.drop(columns=["charttime", "charttimestamp"], inplace=True) # columns: "hadm_id", "itemid", "charttime_interval_after_icu_adm", "value" are left 
    cur_adm_recordings = cur_adm_recordings[cur_adm_recordings["charttime_interval_after_icu_adm"] <= 24] # only keep the recordings in the first 24-hour window range
    cur_adm_recordings.sort_values(by="charttime_interval_after_icu_adm", inplace=True, ignore_index=True)
    cur_adm_itemids = cur_adm_recordings["itemid"].unique()
    cur_adm_gb_itemid = cur_adm_recordings.groupby("itemid")
    final_cur_adm_recordings = 0
    for j, itemid in enumerate(cur_adm_itemids):
        cur_item = cur_adm_gb_itemid.get_group(itemid)
        cur_item_first_value_one_window = cur_item.groupby("charttime_interval_after_icu_adm").first()
        if j == 0:
            final_cur_adm_recordings = cur_item_first_value_one_window
        else:
            final_cur_adm_recordings = pd.concat([final_cur_adm_recordings, cur_item_first_value_one_window])
    final_cur_adm_recordings.reset_index(inplace=True)
    final_cur_adm_recordings = final_cur_adm_recordings.pivot(index="charttime_interval_after_icu_adm", columns="itemid", values="value")
    
    return final_cur_adm_recordings

# %%
with pd.option_context("display.max_rows", None, "display.max_columns", None):
    display(Cur_Patient_24hr_cat_itemids_value(175774))
# Out:
# itemid                            224168  224641  225074  225076  225087  \
# charttime_interval_after_icu_adm
# 1                                    1.0     1.0     0.0     0.0     1.0
# 2                                    NaN     NaN     0.0     0.0     1.0
# 3                                    NaN     NaN     NaN     NaN     NaN
# 4                                    1.0     1.0     0.0     0.0     1.0
# 8                                    1.0     1.0     NaN     NaN     NaN
# 9                                    NaN     NaN     NaN     NaN     NaN
# 12                                   1.0     1.0     NaN     NaN     NaN
# 16                                   1.0     1.0     NaN     NaN     NaN
# 20                                   1.0     1.0     NaN     NaN     NaN
# 23                                   1.0     1.0     NaN     NaN     NaN
# 24                                   NaN     NaN     NaN     NaN     NaN
#
# ...

# %% [markdown]
# # To-do list for chart_mv:
#     * imputation for the output of Cur_Patient_24hr_cat_itemids_value(hadmid)

# %% [markdown]
# * **For chart_cv:**
#     * transfer current patient's cat itemid's recordings into the form with 24 rows, each row represent a one-hour time window
#     * one-hot encoding each original cat itemid based on the form got from the last step

# %% [markdown]
# # test on mimic_chart_CV's categorical itemid

# %% [markdown]
# * **data from file "mimic_chart_CV_reg_pre.csv" is after regular preprocess and can be used directly**

# %%
mimic_chart_CV = pd.read_csv("./data/mimic_chart_CV_reg_pre.csv")
# Out:
# /Users/shutingcui/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (9,11,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
mimic_chart_CV_only_numeric_itemid_data = pd.read_csv("./data/mimic_chart_CV_only_numeric.csv")
patient_chart_cv_only_numeric = set(mimic_chart_CV_only_numeric_itemid_data["hadm_id"].unique())
patient_chart_cv_only_categorical = set(mimic_chart_CV[mimic_chart_CV["itemid"].isin(final_cat_itemid_list_chart_cv)]["hadm_id"].unique())
print(len(patient_chart_cv_only_numeric))
print(len(patient_chart_cv_only_categorical))
print(len(patient_chart_cv_only_numeric.intersection(patient_chart_cv_only_categorical)))
# Out:
# /Users/shutingcui/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (10,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# 26103
# 26067
# 26066

# %%
list_itemid_num_chart_CV = []
initial_list_itemid_non_num_chart_CV = []
itemid_list_chart_CV = mimic_chart_CV["itemid"].unique()
chart_CV_groupby_itemid = mimic_chart_CV[["itemid", "value"]].groupby("itemid")
for i,itemid in enumerate(itemid_list_chart_CV):
    cur_itemid_values = chart_CV_groupby_itemid.get_group(itemid)
    try:
        pd.to_numeric(cur_itemid_values["value"], downcast="float")
        list_itemid_num_chart_CV.append(itemid)
    except ValueError:
        temp = pd.to_numeric(cur_itemid_values["value"].unique(), errors='coerce', downcast='float')
        if np.isnan(temp).sum() != len(temp): # this is the case where the non-numerics are actually -> 
            # numeric but due to some terms like error or no data they have gone into non-numeric set.
            list_itemid_num_chart_CV.append(itemid)
        else:
#             print(itemid)
#             print(cur_itemid_values["value"].unique())
            initial_list_itemid_non_num_chart_CV.append(itemid)
        pass
print("number of numeric temporal variables in mimic_chart_CV data: ", len(list_itemid_num_chart_CV))
print("number of non-numeric temporal variables in mimic_chart_CV data: ", len(initial_list_itemid_non_num_chart_CV))
# Out:
# number of numeric temporal variables in mimic_chart_CV data:  1075
# number of non-numeric temporal variables in mimic_chart_CV data:  953

# %% [markdown]
# ## Applying another two operations on mimic_chart_CV non-numeric temporal variables
# * Selecting only those categorical itemids with <= 10 unique values
# * Selecting only those categorical itemids with recording frequency >= 30%
# * **After the above two steps, 83 selected chart_cv categorical itemids are left**

# %%
list_itemid_cat_chart_CV = []
for itemid in initial_list_itemid_non_num_chart_CV:
    cur_itemid_values = chart_CV_groupby_itemid.get_group(itemid)
    if len(cur_itemid_values["value"].unique()) <= 10: # only select those categorical itemids that has categorical values less than or equal to 10
        list_itemid_cat_chart_CV.append(itemid)
print("Number of categorical itemids in chart cv data is: ", len(list_itemid_cat_chart_CV))
# Out:
# Number of categorical itemids in chart cv data is:  807

# %%
total_patients_num_chart_cv = len(mimic_chart_CV[mimic_chart_CV["itemid"].isin(list_itemid_cat_chart_CV)]["hadm_id"].unique())
cat_itemid_record_fraction_chart_cv = pd.DataFrame(np.zeros((1, len(list_itemid_cat_chart_CV))), columns=list_itemid_cat_chart_CV)
for itemid in list_itemid_cat_chart_CV:
    record_cur_itemid_patients_num = len(mimic_chart_CV[mimic_chart_CV["itemid"]==itemid]["hadm_id"].unique())
    cat_itemid_record_fraction_chart_cv.loc[0][itemid] = record_cur_itemid_patients_num / total_patients_num_chart_cv
    
cat_itemid_record_fraction_chart_cv = cat_itemid_record_fraction_chart_cv.T
cat_itemid_record_fraction_chart_cv.reset_index(inplace=True)

# %%
cat_itemid_record_fraction_chart_cv.rename(columns={"index": "itemid", 0: "fraction of recorded hadmid"}, inplace=True)
cat_itemid_record_fraction_chart_cv.sort_values(by=["fraction of recorded hadmid"], ascending=False, inplace=True, ignore_index=True)

# %%
final_cat_itemid_list_chart_cv = list(cat_itemid_record_fraction_chart_cv[cat_itemid_record_fraction_chart_cv["fraction of recorded hadmid"] >= 0.3]["itemid"])
print(len(final_cat_itemid_list_chart_cv))
# Out:
# 83

# %%
selected_cat_itemid_chart_CV = itemid_info_chart[itemid_info_chart["itemid"].isin(final_cat_itemid_list_chart_cv)][["itemid", "label"]]
selected_cat_itemid_chart_CV.reset_index(inplace=True, drop=True)
selected_cat_itemid_chart_CV
# Out:
#     itemid                  label
# 0     1043    Less Restrict Meas.
# 1     1046           Pain Present
# 2     1047        Range of Motion
# 3     1087     Pain Assess Method
# 4     1089   PainLevel Acceptable
# ..     ...                    ...
# 78    8466  Pupil Response [Left]
# 79    8467      Pupil Size [Left]
# 80    8476     Sputum Consistency
# 81    8477        Sputum [Amount]
# 82    8480     Urine [Appearance]
#
# [83 rows x 2 columns]

# %%
selected_cat_itemid_chart_CV.to_csv("./data/selected_cat_itemid_label_chart_cv.csv")

# %% [markdown]
# # Store the (true_value, mapped_value) pairs for all categorical itemids in chart_cv into file "./data/chart_cv_cat_itemids_unique_value_map.csv"

# %%
cat_itemid_unique_values_map_chart_cv = 0
for i,itemid in enumerate(final_cat_itemid_list_chart_cv):
    cur_itemid_unique_values = list(mimic_chart_CV[mimic_chart_CV["itemid"] == itemid]["value"].dropna().unique())
    cur_value_map_pd = pd.DataFrame(data={"itemid": [itemid]*len(cur_itemid_unique_values), "true_unique_value": cur_itemid_unique_values, "mapped_value": [str(itemid)+"_"+str(j) for j in range(1,len(cur_itemid_unique_values)+1)]})
    if i == 0:
        cat_itemid_unique_values_map_chart_cv = cur_value_map_pd
    else:
        cat_itemid_unique_values_map_chart_cv = pd.concat([cat_itemid_unique_values_map_chart_cv, cur_value_map_pd])

# %%
cat_itemid_unique_values_map_chart_cv.reset_index(inplace=True, drop=True)
with pd.option_context("display.max_rows", None, "display.max_columns", None):
    display(cat_itemid_unique_values_map_chart_cv)
# Out:
#      itemid true_unique_value mapped_value
# 0       184   4 Spontaneously        184_1
# 1       184     1 No Response        184_2
# 2       184       3 To speech        184_3
# 3       184         2 To pain        184_4
# 4       723        5 Oriented        723_1
# 5       723        4 Confused        723_2
# 6       723      1.0 ET/Trach        723_3
# 7       723     1 No Response        723_4
# 8       723   2 Incomp sounds        723_5
# 9       723  3 Inapprop words        723_6
# 10      617        Tachypneic        617_1
# 11      617           Regular        617_2
# 12      617         Irregular        617_3
# 13      617     Cheyne-Stokes        617_4
# 14      617     Discoordinate        617_5
# 15      617     Other/Remarks        617_6
# 16      617            Apneic        617_7
# 17      617          Kussmaul        617_8
# 18      454  6 Obeys Commands        454_1
# 19      454  5 Localizes Pain        454_2
# 20      454  4 Flex-withdraws        454_3
# ...

# %%
cat_itemid_unique_values_map_chart_cv.to_csv("./data/chart_cv_cat_itemids_unique_value_map.csv", index=False)

# %% [markdown]
# # transfer all selected chart_cv categorical itemids' "value" based on the above map pairs
# * code block [68] contains the transform operation
# * code block [72] are checking whether transfering successfully (successfully)

# %%
for itemid in final_cat_itemid_list_chart_cv:
    cur_itemid_org_values = list(cat_itemid_unique_values_map_chart_cv[cat_itemid_unique_values_map_chart_cv["itemid"]==itemid]["true_unique_value"])
    cur_itemid_mapped_values = list(cat_itemid_unique_values_map_chart_cv[cat_itemid_unique_values_map_chart_cv["itemid"]==itemid]["mapped_value"])
    cur_dict = dict(zip(cur_itemid_org_values, cur_itemid_mapped_values))
    mimic_chart_CV.loc[mimic_chart_CV["itemid"]==itemid,['value']] = mimic_chart_CV[mimic_chart_CV["itemid"]==itemid]["value"].map(cur_dict)

# %%
for itemid in final_cat_itemid_list_chart_cv:
    print(itemid)
    print(mimic_chart_CV[mimic_chart_CV["itemid"]==itemid]["value"].value_counts())
# Out:
# 184
# 184_1    128233
# 184_3     34935
# 184_2     29750
# 184_4     10245
# Name: value, dtype: int64
# 723
# 723_1    109277
# 723_3     68454
# 723_2     15573
# 723_4      4074
# 723_5      3475
# 723_6      1562
# Name: value, dtype: int64
# 617
# 617_2    183538
# 617_1      7484
# 617_3      1254
# 617_6       267
# 617_5       221
# 617_4       156
# 617_7       129
# 617_8        30
# Name: value, dtype: int64
# 454
# 454_1    150774
# 454_2     22556
# 454_4     15076
# 454_3     11825
# 454_6      1079
# 454_5       817
# Name: value, dtype: int64
# 674
# 674_2    119405
# 674_1    111762
# 674_4     19699
# 674_3      5133
# 674_5        95
# 674_6        68
# Name: value, dtype: int64
# 478
# 478_1    143073
# 478_3      2458
# 478_4      1940
# 478_5      1916
# 478_2       962
# 478_7       770
# 478_6       683
# 478_9        67
# 478_8        40
# Name: value, dtype: int64
# 80
# 80_1    87634
# 80_2    26313
# 80_3    22899
# 80_4      811
# 80_5       54
# ...

# %% [markdown]
# # Next step:
# * one-hot-encoding itemid in "final_cat_itemid_list_chart_cv"
# * transfer the itemid in the form same with numeric itemid with 24 rows represend 24 one-hour time window
# * applying imputation work same as numeric itemid
# * concatenate the numeric itemid and categorical itemid transformed data as the input for the KMF algorithm

# %%
final_chart_cv_cat_itemid_recordings = mimic_chart_CV[mimic_chart_CV["itemid"].isin(final_cat_itemid_list_chart_cv)]
print(len(final_cat_itemid_list_chart_cv))
final_chart_cv_cat_itemid_recordings.shape
# Out:
# 83
# (9755444, 18)

# %%
final_chart_cv_cat_itemid_recordings.head()
# Out:
#        Unnamed: 0    row_id  subject_id  hadm_id  icustay_id  itemid  \
# 33585       33991  34360891          30   104557    225176.0     283
# 33591       33997  34332845          13   143045    263738.0     283
# 33595       34002  34339444          17   161087    257980.0     283
# 40036       40461  34337424          17   194023    277042.0     283
# 40037       40462  34337425          17   194023    277042.0     284
#
#                  charttime            storetime   cgid  value  valuenum  \
# 33585  2172-10-14 19:00:00  2172-10-14 19:38:00  16018  283_1       NaN
# 33591  2167-01-09 00:00:00  2167-01-09 02:29:00  16866  283_1       NaN
# 33595  2135-05-10 07:00:00  2135-05-10 06:59:00  15039  283_1       NaN
# 40036  2134-12-28 16:00:00  2134-12-28 15:52:00  15652  283_1       NaN
# 40037  2134-12-28 16:00:00  2134-12-28 15:52:00  15652  284_1       NaN
#
#       valueuom  warning  error resultstatus   stopped  expire_flag dbsource
# ...

# %%
pd.get_dummies(final_chart_cv_cat_itemid_recordings["value"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-87-137b2b6615c7> in <module>
# ----> 1 pd.get_dummies(final_chart_cv_cat_itemid_recordings["value"])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/displayhook.py in __call__(self, result)
#     260             self.start_displayhook()
#     261             self.write_output_prompt()
# --> 262             format_dict, md_dict = self.compute_format_data(result)
#     263             self.update_user_ns(result)
#     264             self.fill_exec_result(result)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# --> 151         return self.shell.display_formatter.format(result)
#     152
#     153     # This can be set to True by the write_output_prompt method in a subclass
#
# ...

# %%
def Cur_Patient_24hr_cat_itemids_value(hadm_id, era):
    if era == "MV":
        cur_dataset_af_gb_hadmid = final_chart_mv_cat_itemid_recordings.groupby("hadm_id")
    if era == "CV":
        cur_dataset_af_gb_hadmid = final_chart_cv_cat_itemid_recordings.groupby("hadm_id")
    
    cur_adm_recordings = cur_dataset_af_gb_hadmid.get_group(hadm_id)[["hadm_id", "itemid", "charttime", "value"]]
    cur_icu_adm_time = mimic_icu_adm[mimic_icu_adm["hadm_id"] == hadm_id]["intime"].unique()[0]
    icu_adm_timestamp = datetime.datetime.timestamp(datetime.datetime.strptime(cur_icu_adm_time,"%Y-%m-%d %H:%M:%S"))
    cur_adm_recordings[["charttimestamp"]] = cur_adm_recordings[["charttime"]].apply((lambda x: datetime.datetime.timestamp(datetime.datetime.strptime(x["charttime"],"%Y-%m-%d %H:%M:%S"))), axis=1)
    cur_adm_recordings[["charttime_interval_after_icu_adm"]] = (cur_adm_recordings[["charttimestamp"]] - icu_adm_timestamp) / 3600
    cur_adm_recordings[["charttime_interval_after_icu_adm"]] = cur_adm_recordings[["charttime_interval_after_icu_adm"]].astype(int) + 1 # "+1" because astype(int) will only keep the integer part of the float number
    # for example: charttime_interval_after_icu_adm == 0.2, actually this belongs to the first one-hour window, so the result should be 1, not 0 (if returned directly by astype(int))
    cur_adm_recordings.drop(columns=["charttime", "charttimestamp"], inplace=True) # columns: "hadm_id", "itemid", "charttime_interval_after_icu_adm", "value" are left 
    cur_adm_recordings = cur_adm_recordings[cur_adm_recordings["charttime_interval_after_icu_adm"] <= 24] # only keep the recordings in the first 24-hour window range
    cur_adm_recordings.sort_values(by="charttime_interval_after_icu_adm", inplace=True, ignore_index=True)
    cur_adm_itemids = cur_adm_recordings["itemid"].unique()
    cur_adm_gb_itemid = cur_adm_recordings.groupby("itemid")
    final_cur_adm_recordings = 0
    for j, itemid in enumerate(cur_adm_itemids):
        cur_item = cur_adm_gb_itemid.get_group(itemid)
        cur_item_first_value_one_window = cur_item.groupby("charttime_interval_after_icu_adm").first()
        if j == 0:
            final_cur_adm_recordings = cur_item_first_value_one_window
        else:
            final_cur_adm_recordings = pd.concat([final_cur_adm_recordings, cur_item_first_value_one_window])
    final_cur_adm_recordings.reset_index(inplace=True)
    final_cur_adm_recordings = final_cur_adm_recordings.pivot(index="charttime_interval_after_icu_adm", columns="itemid", values="value")
    
    return final_cur_adm_recordings

# %%
with pd.option_context("display.max_rows", None, "display.max_columns", None):
    display(Cur_Patient_24hr_cat_itemids_value(104557, "CV"))
# Out:
# itemid                            31    32    49    80    82    83    84    \
# charttime_interval_after_icu_adm
# 1                                  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2                                 31_2  32_2  49_1  80_1   NaN   NaN   NaN
# 3                                 31_2  32_2  49_1   NaN  82_1  83_1  84_1
# 4                                  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5                                 31_2  32_2  49_1   NaN   NaN   NaN   NaN
# 6                                  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 7                                  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 8                                  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9                                 31_2  32_2  49_1   NaN   NaN   NaN   NaN
# 10                                31_2  32_2  49_1   NaN   NaN   NaN   NaN
# 11                                31_2  32_3  49_1   NaN   NaN   NaN   NaN
# ...

# %% [markdown]
# # function "One_Hot_Cat_itemid_chart_CV":
# * input: one patient's transformed categorical itemid's recordings in chart_CV
# * output: one-hot encoded version of the input

# %%
temp_cat_itemid_recording = Cur_Patient_24hr_cat_itemids_value(104557, "CV")
cur_itemid_dummy = pd.get_dummies(temp_cat_itemid_recording[31])
temp_new_cat_itemid_recording = pd.concat([temp_cat_itemid_recording, cur_itemid_dummy], axis=1)
with pd.option_context("display.max_rows", None, "display.max_columns", None):
    display(temp_new_cat_itemid_recording)
# Out:
#                                     31    32    49    80    82    83    84  \
# charttime_interval_after_icu_adm
# 1                                  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2                                 31_2  32_2  49_1  80_1   NaN   NaN   NaN
# 3                                 31_2  32_2  49_1   NaN  82_1  83_1  84_1
# 4                                  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5                                 31_2  32_2  49_1   NaN   NaN   NaN   NaN
# 6                                  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 7                                  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 8                                  NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 9                                 31_2  32_2  49_1   NaN   NaN   NaN   NaN
# 10                                31_2  32_2  49_1   NaN   NaN   NaN   NaN
# 11                                31_2  32_3  49_1   NaN   NaN   NaN   NaN
# ...

# %%
def One_Hot_Cat_itemid_chart_CV(org_trans_itemid):
